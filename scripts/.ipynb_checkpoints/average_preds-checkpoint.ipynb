# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
from label_to_cat import LABEL_TO_CAT

datapath = '../input/predict_probs_resnet50.h5'
BATCHES_COUNT = 12091

# %%
store = pd.HDFStore(datapath)
print('{} tables in storage'.format(len(store)))
# keys = store.keys()
# Out:
# 12091 tables in storage

# %%
store.select('d12090')
# Out:
#         pr_id  img_num             1             2             3    4  \
# 0    23615052        1  0.000000e+00  0.000000e+00  0.000000e+00  0.0
# 1    23615052        1  0.000000e+00  0.000000e+00  0.000000e+00  0.0
# 2    23615052        1  0.000000e+00  0.000000e+00  0.000000e+00  0.0
# 3    23615052        1  0.000000e+00  0.000000e+00  0.000000e+00  0.0
# 4    23615052        1  0.000000e+00  0.000000e+00  0.000000e+00  0.0
# 5    23615052        1  0.000000e+00  0.000000e+00  0.000000e+00  0.0
# 6    23615052        1  0.000000e+00  0.000000e+00  0.000000e+00  0.0
# 7    23615052        1  0.000000e+00  0.000000e+00  0.000000e+00  0.0
# 8    23615052        1  0.000000e+00  0.000000e+00  0.000000e+00  0.0
# 9    23615052        1  0.000000e+00  0.000000e+00  0.000000e+00  0.0
# 10   23615124        0  0.000000e+00  7.092953e-06  0.000000e+00  0.0
# 11   23615124        0  0.000000e+00  2.324581e-06  0.000000e+00  0.0
# ...

# %%
# %%time
keys = store.keys()
# Out:
# CPU times: user 39.2 s, sys: 228 ms, total: 39.4 s
# Wall time: 39.4 s

# %%
assert len(keys) == BATCHES_COUNT

preds = []
for key in tqdm(keys): 
    table = store.select(key)
    table.drop(table[table.img_num != 0.].index, axis=0, inplace=True)
    assert table.shape[0] % 10 == 0
    for i in range(int(table.shape[0] / 10)):
        product_id = table.pr_id.iloc[10*i]
        id_ = int(table[10*i: 10*i + 5].drop(['pr_id', 'img_num'], axis=1, inplace=False).sum().idxmax()) - 1
        assert 0 <= id_ < 5270
        cat = LABEL_TO_CAT[id_]
        preds.append((int(product_id), cat))

preds_df = pd.DataFrame(data=preds, columns=['_id','category_id'])
preds_df.to_csv('preds_resnet50_first_five.csv', index=False)
# Out:
# 100%|██████████| 12091/12091 [1:10:59<00:00,  2.84it/s]
