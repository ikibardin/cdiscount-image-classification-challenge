# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
from label_to_cat import LABEL_TO_CAT

datapath = '../input/inception3_test.h5'
BATCHES_COUNT = 12091

# %%
# %%time
store = pd.HDFStore(datapath)
keys = store.keys()
print('{} tables in storage'.format(len(keys)))
# Out:
# 3 tables in storage
# CPU times: user 16 ms, sys: 0 ns, total: 16 ms
# Wall time: 16.2 ms

# %%
store.select('d0')
# Out:
#      pr_id  img_num             1             2             3             4  \
# 0       14        0  1.430511e-06  8.404255e-06  2.384186e-07  4.589558e-06
# 1       49        0  2.801418e-06  8.404255e-06  1.668930e-06  7.212162e-06
# 2       85        0  2.563000e-06  1.430511e-06  1.788139e-07  2.980232e-06
# 3       86        0  5.197525e-05  5.006790e-04  5.483627e-06  2.890825e-05
# 4       93        0  3.576279e-07  8.940697e-07  1.192093e-07  8.344650e-07
# 5       94        0  3.337860e-06  1.071095e-04  2.026558e-06  1.388788e-05
# 6       96        0  7.510185e-06  1.901388e-04  3.278255e-06  2.020597e-05
# 7       96        1  5.245209e-06  1.519918e-04  2.682209e-06  1.454353e-05
# 8       96        2  7.510185e-06  1.568794e-04  2.205372e-06  1.895428e-05
# 9      110        0  2.980232e-06  4.059076e-05  7.152557e-07  9.655952e-06
# 10     110        1  8.046627e-06  5.763769e-05  1.013279e-06  8.761883e-06
# ...
